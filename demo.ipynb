# %%
import torch
import numpy as np
import clip
from PIL import Image
import requests

device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

image = preprocess(image).unsqueeze(0).to(device)
text = clip.tokenize(["a diagram", "a dog", "a cat"]).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 12
#       9 url = "http://images.cocodataset.org/val2017/000000039769.jpg"
#      10 image = Image.open(requests.get(url, stream=True).raw)
# ---> 12 image = preprocess(image).unsqueeze(0).to(device)
#      13 text = clip.tokenize(["a diagram", "a dog", "a cat"]).to(device)
#      15 with torch.no_grad():
#
# File c:\Users\hokha\anaconda3\envs\demo2\Lib\site-packages\torchvision\transforms\transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File c:\Users\hokha\anaconda3\envs\demo2\Lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File c:\Users\hokha\anaconda3\envs\demo2\Lib\site-packages\torchvision\transforms\functional.py:168, in to_tensor(pic)
#     166 # handle PIL Image
#     167 mode_to_nptype = {"I": np.int32, "I;16" if sys.byteorder == "little" else "I;16B": np.int16, "F": np.float32}
# --> 168 img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     170 if pic.mode == "1":
#     171     img = 255 * img
#
# RuntimeError: Numpy is not available

# %%
import pickle

em = None

with open(r'C:\Users\hokha\OneDrive\Desktop\workplace\AIC-2024\backend\ai\faiss_index\index_pickle.pkl', 'wb') as f:
    em = pickle.load(f)

for i in em:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[3], line 6
#       3 em = None
#       5 with open(r'C:\Users\hokha\OneDrive\Desktop\workplace\AIC-2024\backend\ai\faiss_index\index_pickle.pkl', 'wb') as f:
# ----> 6     em = pickle.load(f)
#       8 for i in em:
#       9     print(i)
#
# UnsupportedOperation: read
